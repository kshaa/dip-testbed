# %%
import pandas as pd

demo1 = pd.read_json("./demo_1.json")
df1 = pd.DataFrame(demo1)

demo2 = pd.read_json("./demo_2.json")
df2 = pd.DataFrame(demo2)

# %%
df1.plot(x='time', y='mag_x')
df1.plot(x='time', y='mag_y')
df1.plot(x='time', y='mag_z')
df1.plot(x='time', y='temp')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df2.plot(x='time', y='acc_x')
df2.plot(x='time', y='acc_y')
df2.plot(x='time', y='acc_z')
df2.plot(x='time', y='gyro_x')
df2.plot(x='time', y='gyro_y')
df2.plot(x='time', y='gyro_z')
# Out:
# <AxesSubplot:xlabel='time'>
